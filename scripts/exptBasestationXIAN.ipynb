# %%
# -*- coding: utf-8 -*-
""" 
Usage:
    THEANO_FLAGS="device=gpu0" python exptBasestationXIAN.py
"""
from __future__ import print_function
import sys
sys.path.insert(0, '..')
import os
import pickle
import numpy as np
import math
import h5py

from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from deepst.models.STResNet import stresnet
from deepst.config import Config
import deepst.metrics as metrics
from deepst.datasets import BasestationXIAN
np.random.seed(1337)  # for reproducibility

# parameters
# data path, you may set your own data path with the global envirmental
# variable DATAPATH
DATAPATH = Config().DATAPATH
nb_epoch = 500  # number of epoch at training stage
nb_epoch_cont = 100  # number of epoch at training (cont) stage
batch_size = 32  # batch size
T = 48  # number of time intervals in one day
nbfilter=64
lr = 0.0002  # learning rate
len_closeness = 3  # length of closeness dependent sequence
len_period = 0  # length of peroid dependent sequence
len_trend = 0  # length of trend dependent sequence
nb_residual_unit = 4   # number of residual units

nb_flow = 2  # there are two types of flows: new-flow and end-flow
# divide data into two subsets: Train & Test, of which the test set is the
# last 10 days
days_test = 4
len_test = T * days_test
map_height, map_width = 20, 20  # grid size
# For NYC Bike data, there are 81 available grid-based areas, each of
# which includes at least ONE bike station. Therefore, we modify the final
# RMSE by multiplying the following factor (i.e., factor).
nb_area = 20 * 20
m_factor = math.sqrt(1. * map_height * map_width / nb_area)
print('factor: ', m_factor)
path_result = 'RET'
path_model = 'MODEL'

if os.path.isdir(path_result) is False:
    os.mkdir(path_result)
if os.path.isdir(path_model) is False:
    os.mkdir(path_model)
# Out:
# Using TensorFlow backend.
# factor:  1.0

# %%
def build_model(external_dim, nbfilter=64):
    c_conf = (len_closeness, nb_flow, map_height,
              map_width) if len_closeness > 0 else None
    p_conf = (len_period, nb_flow, map_height,
              map_width) if len_period > 0 else None
    t_conf = (len_trend, nb_flow, map_height,
              map_width) if len_trend > 0 else None

    model = stresnet(c_conf=c_conf, p_conf=p_conf, t_conf=t_conf,
                     external_dim=external_dim, nb_residual_unit=nb_residual_unit, nbfilter=nbfilter)
    adam = Adam(lr=lr)
    model.compile(loss='mse', optimizer=adam, metrics=[metrics.rmse])
    model.summary()
    # from keras.utils.visualize_util import plot
    # plot(model, to_file='model.png', show_shapes=True)
    return model


def main():
    # load data
    print("loading data...")
    X_train, Y_train, X_test, Y_test, mmn, external_dim, timestamp_train, timestamp_test = BasestationXIAN.load_data(
        T=T, nb_flow=nb_flow, len_closeness=len_closeness, len_period=len_period, len_trend=len_trend, len_test=len_test,
        preprocess_name='preprocessing.pkl', meta_data=False)

    print("\n days (test): ", [v[:8] for v in timestamp_test[0::T]])

    print('=' * 10)
    print("compiling model...")
    print(
        "**at the first time, it takes a few minites to compile if you use [Theano] as the backend**")
    print("before build_model")
    model = build_model(external_dim, nbfilter=nbfilter)
    print("after build_model")
    hyperparams_name = 'c{}.p{}.t{}.resunit{}.lr{}'.format(
        len_closeness, len_period, len_trend, nb_residual_unit, lr)
    fname_param = os.path.join('MODEL', '{}.best.h5'.format(hyperparams_name))

    early_stopping = EarlyStopping(monitor='val_rmse', patience=5, mode='min')
    model_checkpoint = ModelCheckpoint(
        fname_param, monitor='val_rmse', verbose=0, save_best_only=True, mode='min')

    print('=' * 10)
    print("training model...")
    history = model.fit(X_train, Y_train,
                        nb_epoch=nb_epoch,
                        batch_size=batch_size,
                        validation_split=0.143,
                        callbacks=[early_stopping, model_checkpoint],
                        verbose=2)
    model.save_weights(os.path.join(
        'MODEL', '{}.h5'.format(hyperparams_name)), overwrite=True)
    pickle.dump((history.history), open(os.path.join(
        path_result, '{}.history.pkl'.format(hyperparams_name)), 'wb'))

    print('=' * 10)
    print('evaluating using the model that has the best loss on the valid set')

    model.load_weights(fname_param)
    score = model.evaluate(X_train, Y_train, batch_size=Y_train.shape[
                           0] // 48, verbose=0)
    print('Train score: %.6f rmse (norm): %.6f rmse (real): %.6f' %
          (score[0], score[1], score[1] * (mmn._max - mmn._min) * m_factor))

    score = model.evaluate(
        X_test, Y_test, batch_size=Y_test.shape[0], verbose=0)
    print('Test score: %.6f rmse (norm): %.6f rmse (real): %.6f' %
          (score[0], score[1], score[1] * (mmn._max - mmn._min) * m_factor))

    print('=' * 10)
    print("training model (cont)...")
    fname_param = os.path.join(
        'MODEL', '{}.cont.best.h5'.format(hyperparams_name))
    model_checkpoint = ModelCheckpoint(
        fname_param, monitor='rmse', verbose=0, save_best_only=True, mode='min')
    history = model.fit(X_train, Y_train, nb_epoch=nb_epoch_cont, verbose=1, batch_size=batch_size, callbacks=[
                        model_checkpoint], validation_data=(X_test, Y_test))
    pickle.dump((history.history), open(os.path.join(
        path_result, '{}.cont.history.pkl'.format(hyperparams_name)), 'wb'))
    model.save_weights(os.path.join(
        'MODEL', '{}_cont.h5'.format(hyperparams_name)), overwrite=True)

    print('=' * 10)
    print('evaluating using the final model')
     
    score = model.evaluate(X_train, Y_train, batch_size=Y_train.shape[
                           0] // 48, verbose=0)
    print('Train score: %.6f rmse (norm): %.6f rmse (real): %.6f' %
          (score[0], score[1], score[1] * (mmn._max - mmn._min) * m_factor))

    score2 = model.predict(X_test, batch_size=Y_test.shape[0], verbose=0)
    file_temp = h5py.File("prediction", "w")
    file_temp.create_dataset("prediction", data=score2)
    file_temp.create_dataset("real", data=Y_test)
    score = model.evaluate(
        X_test, Y_test, batch_size=Y_test.shape[0], verbose=0)
    print('Test score: %.6f rmse (norm): %.6f rmse (real): %.6f' %
          (score[0], score[1], score[1] * (mmn._max - mmn._min) * m_factor))

if __name__ == '__main__':
    main()
# Out:
# loading data...
# incomplete days:  []
# train_data shape:  (1344, 2, 20, 20)
# min: 0.0 max: 735.0
# XC shape:  (1533, 6, 20, 20) XP shape:  (0,) XT shape:  (0,) Y shape: (1533, 2, 20, 20)
# XC shape:  (1533, 6, 20, 20) XP shape:  (1, 0) XT shape:  (1, 0) Y shape: (1533, 2, 20, 20)
# train shape: (1341, 6, 20, 20) (1341, 2, 20, 20) test shape:  (192, 6, 20, 20) (192, 2, 20, 20)
# (1341, 6, 20, 20)
#
# (192, 6, 20, 20)
#
#
#  days (test):  [b'20150117', b'20150118', b'20150119', b'20150120']
# ==========
# compiling model...
# **at the first time, it takes a few minites to compile if you use [Theano] as the backend**
# before build_model
# external_dim: None
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 6, 20, 20)     0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)  (None, 64, 20, 20)    3520        input_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 64, 20, 20)    0           convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)  (None, 64, 20, 20)    36928       activation_1[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 64, 20, 20)    0           convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)  (None, 64, 20, 20)    36928       activation_2[0][0]
# ____________________________________________________________________________________________________
# merge_1 (Merge)                  (None, 64, 20, 20)    0           convolution2d_1[0][0]
#                                                                    convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 64, 20, 20)    0           merge_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)  (None, 64, 20, 20)    36928       activation_3[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 64, 20, 20)    0           convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)  (None, 64, 20, 20)    36928       activation_4[0][0]
# ____________________________________________________________________________________________________
# merge_2 (Merge)                  (None, 64, 20, 20)    0           merge_1[0][0]
#                                                                    convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 64, 20, 20)    0           merge_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_6 (Convolution2D)  (None, 64, 20, 20)    36928       activation_5[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 64, 20, 20)    0           convolution2d_6[0][0]
# ____________________________________________________________________________________________________
# convolution2d_7 (Convolution2D)  (None, 64, 20, 20)    36928       activation_6[0][0]
# ____________________________________________________________________________________________________
# merge_3 (Merge)                  (None, 64, 20, 20)    0           merge_2[0][0]
#                                                                    convolution2d_7[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, 64, 20, 20)    0           merge_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8 (Convolution2D)  (None, 64, 20, 20)    36928       activation_7[0][0]
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, 64, 20, 20)    0           convolution2d_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_9 (Convolution2D)  (None, 64, 20, 20)    36928       activation_8[0][0]
# ____________________________________________________________________________________________________
# merge_4 (Merge)                  (None, 64, 20, 20)    0           merge_3[0][0]
#                                                                    convolution2d_9[0][0]
# ____________________________________________________________________________________________________
# activation_9 (Activation)        (None, 64, 20, 20)    0           merge_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_10 (Convolution2D) (None, 2, 20, 20)     1154        activation_9[0][0]
# ____________________________________________________________________________________________________
# activation_10 (Activation)       (None, 2, 20, 20)     0           convolution2d_10[0][0]
# ====================================================================================================
# Total params: 300,098
# Trainable params: 300,098
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# after build_model
# ==========
# training model...
# Train on 1149 samples, validate on 192 samples
# Epoch 1/500
# 3s - loss: 5.1515e-04 - rmse: 0.0214 - val_loss: 2.4911e-04 - val_rmse: 0.0157
# Epoch 2/500
# 2s - loss: 1.8522e-04 - rmse: 0.0135 - val_loss: 1.8735e-04 - val_rmse: 0.0136
# Epoch 3/500
# 2s - loss: 1.4974e-04 - rmse: 0.0122 - val_loss: 1.6017e-04 - val_rmse: 0.0126
# Epoch 4/500
# 2s - loss: 1.4844e-04 - rmse: 0.0120 - val_loss: 1.8342e-04 - val_rmse: 0.0135
# Epoch 5/500
# 2s - loss: 1.5049e-04 - rmse: 0.0121 - val_loss: 1.7739e-04 - val_rmse: 0.0133
# Epoch 6/500
# 2s - loss: 1.2314e-04 - rmse: 0.0110 - val_loss: 1.4486e-04 - val_rmse: 0.0120
# Epoch 7/500
# 2s - loss: 1.1940e-04 - rmse: 0.0109 - val_loss: 1.5270e-04 - val_rmse: 0.0123
# Epoch 8/500
# 2s - loss: 1.1750e-04 - rmse: 0.0108 - val_loss: 1.3333e-04 - val_rmse: 0.0115
# Epoch 9/500
# 2s - loss: 1.1056e-04 - rmse: 0.0104 - val_loss: 1.2754e-04 - val_rmse: 0.0113
# Epoch 10/500
# 2s - loss: 1.2102e-04 - rmse: 0.0108 - val_loss: 1.4393e-04 - val_rmse: 0.0119
# Epoch 11/500
# 2s - loss: 1.1576e-04 - rmse: 0.0107 - val_loss: 1.2569e-04 - val_rmse: 0.0112
# Epoch 12/500
# 2s - loss: 1.0977e-04 - rmse: 0.0104 - val_loss: 1.4335e-04 - val_rmse: 0.0119
# Epoch 13/500
# 2s - loss: 1.0913e-04 - rmse: 0.0104 - val_loss: 1.2717e-04 - val_rmse: 0.0112
# Epoch 37/500
# 2s - loss: 8.8664e-05 - rmse: 0.0093 - val_loss: 1.1045e-04 - val_rmse: 0.0105
# Epoch 38/500
# 2s - loss: 9.8049e-05 - rmse: 0.0098 - val_loss: 1.0310e-04 - val_rmse: 0.0101
# Epoch 39/500
# 2s - loss: 9.0320e-05 - rmse: 0.0094 - val_loss: 1.0292e-04 - val_rmse: 0.0101
# Epoch 40/500
# 2s - loss: 8.8691e-05 - rmse: 0.0094 - val_loss: 1.0054e-04 - val_rmse: 0.0100
# Epoch 41/500
# 2s - loss: 9.1402e-05 - rmse: 0.0095 - val_loss: 1.0481e-04 - val_rmse: 0.0102
# Epoch 42/500
# 2s - loss: 9.2666e-05 - rmse: 0.0095 - val_loss: 1.2233e-04 - val_rmse: 0.0111
# Epoch 43/500
# 2s - loss: 8.6559e-05 - rmse: 0.0093 - val_loss: 1.0011e-04 - val_rmse: 0.0100
# Epoch 44/500
# 2s - loss: 8.4875e-05 - rmse: 0.0092 - val_loss: 1.0457e-04 - val_rmse: 0.0102
# Epoch 45/500
# 2s - loss: 8.5243e-05 - rmse: 0.0092 - val_loss: 9.7979e-05 - val_rmse: 0.0099
# Epoch 46/500
# 2s - loss: 8.2459e-05 - rmse: 0.0090 - val_loss: 1.0419e-04 - val_rmse: 0.0102
# Epoch 47/500
# 2s - loss: 8.2590e-05 - rmse: 0.0090 - val_loss: 9.9401e-05 - val_rmse: 0.0099
# Epoch 48/500
# 2s - loss: 8.3760e-05 - rmse: 0.0091 - val_loss: 1.0022e-04 - val_rmse: 0.0100
# Epoch 49/500
# 2s - loss: 8.2620e-05 - rmse: 0.0090 - val_loss: 1.0190e-04 - val_rmse: 0.0101
# Epoch 50/500
# 2s - loss: 8.1364e-05 - rmse: 0.0090 - val_loss: 1.1678e-04 - val_rmse: 0.0107
# Epoch 51/500
# 2s - loss: 8.1109e-05 - rmse: 0.0089 - val_loss: 1.0621e-04 - val_rmse: 0.0103
# ==========
# evaluating using the model that has the best loss on the valid set
# Train score: 0.000083 rmse (norm): 0.009059 rmse (real): 6.658018
# Test score: 0.000095 rmse (norm): 0.009737 rmse (real): 7.156642
# ==========
# training model (cont)...
# Train on 1341 samples, validate on 192 samples
# Epoch 1/100
# 1341/1341 [==============================] - 3s - loss: 8.7107e-05 - rmse: 0.0093 - val_loss: 9.5601e-05 - val_rmse: 0.0097
# Epoch 2/100
# 1341/1341 [==============================] - 3s - loss: 9.4502e-05 - rmse: 0.0097 - val_loss: 9.7345e-05 - val_rmse: 0.0098
# Epoch 3/100
# 1341/1341 [==============================] - 3s - loss: 8.7673e-05 - rmse: 0.0093 - val_loss: 9.8652e-05 - val_rmse: 0.0099
# Epoch 4/100
# 1341/1341 [==============================] - 3s - loss: 8.5779e-05 - rmse: 0.0092 - val_loss: 9.5203e-05 - val_rmse: 0.0097
# Epoch 5/100
# 1341/1341 [==============================] - 3s - loss: 8.6445e-05 - rmse: 0.0092 - val_loss: 1.0674e-04 - val_rmse: 0.0103
# Epoch 83/100
# 1341/1341 [==============================] - 6s - loss: 5.8945e-05 - rmse: 0.0076 - val_loss: 8.6013e-05 - val_rmse: 0.0092
# Epoch 84/100
# 1341/1341 [==============================] - 6s - loss: 5.6741e-05 - rmse: 0.0075 - val_loss: 8.8003e-05 - val_rmse: 0.0093
# Epoch 85/100
# 1341/1341 [==============================] - 6s - loss: 5.4747e-05 - rmse: 0.0074 - val_loss: 9.0217e-05 - val_rmse: 0.0094
# Epoch 86/100
# 1341/1341 [==============================] - 6s - loss: 5.4145e-05 - rmse: 0.0073 - val_loss: 8.7745e-05 - val_rmse: 0.0093
# Epoch 87/100
# 1341/1341 [==============================] - 6s - loss: 5.3733e-05 - rmse: 0.0073 - val_loss: 8.7419e-05 - val_rmse: 0.0093
# Epoch 88/100
# 1341/1341 [==============================] - 6s - loss: 5.3390e-05 - rmse: 0.0073 - val_loss: 8.7125e-05 - val_rmse: 0.0093
# Epoch 89/100
# 1341/1341 [==============================] - 6s - loss: 5.5967e-05 - rmse: 0.0074 - val_loss: 8.8022e-05 - val_rmse: 0.0093
# Epoch 90/100
# 1341/1341 [==============================] - 6s - loss: 5.5776e-05 - rmse: 0.0074 - val_loss: 8.7387e-05 - val_rmse: 0.0093
# Epoch 91/100
# 1341/1341 [==============================] - 6s - loss: 5.6563e-05 - rmse: 0.0075 - val_loss: 9.3313e-05 - val_rmse: 0.0096
# Epoch 92/100
# 1341/1341 [==============================] - 6s - loss: 5.4916e-05 - rmse: 0.0074 - val_loss: 9.2703e-05 - val_rmse: 0.0096
# Epoch 93/100
# 1341/1341 [==============================] - 6s - loss: 5.7169e-05 - rmse: 0.0075 - val_loss: 9.3462e-05 - val_rmse: 0.0096
# Epoch 94/100
# 1341/1341 [==============================] - 6s - loss: 5.3403e-05 - rmse: 0.0073 - val_loss: 8.6849e-05 - val_rmse: 0.0093
# Epoch 95/100
# 1341/1341 [==============================] - 6s - loss: 5.1886e-05 - rmse: 0.0072 - val_loss: 1.0403e-04 - val_rmse: 0.0101
# Epoch 96/100
# 1341/1341 [==============================] - 6s - loss: 5.4174e-05 - rmse: 0.0073 - val_loss: 9.0701e-05 - val_rmse: 0.0094
# Epoch 97/100
# 1341/1341 [==============================] - 6s - loss: 5.5126e-05 - rmse: 0.0074 - val_loss: 9.0536e-05 - val_rmse: 0.0094
# Epoch 98/100
# 1341/1341 [==============================] - 6s - loss: 5.2964e-05 - rmse: 0.0073 - val_loss: 8.6450e-05 - val_rmse: 0.0092
# Epoch 99/100
# 1341/1341 [==============================] - 6s - loss: 4.9197e-05 - rmse: 0.0070 - val_loss: 8.6785e-05 - val_rmse: 0.0092
# Epoch 100/100
# 1341/1341 [==============================] - 6s - loss: 5.0179e-05 - rmse: 0.0071 - val_loss: 8.7242e-05 - val_rmse: 0.0093
# ==========
# evaluating using the final model
# Train score: 0.000051 rmse (norm): 0.007123 rmse (real): 5.235180
# Test score: 0.000087 rmse (norm): 0.009340 rmse (real): 6.865138
# {
#   "status": 1
# }
